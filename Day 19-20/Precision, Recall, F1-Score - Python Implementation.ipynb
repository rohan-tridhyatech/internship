# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
heart_data = pd.read_csv("/content/heart_1.csv")

# %%
heart_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_data.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
heart_data.shape
# Out:
# (303, 14)

# %%
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
heart_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
heart_data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
heart_data["target"].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %% [markdown]
# 1 --> Defective Heart
#
# 0 --> Healthy Heart

# %%
X = heart_data.drop(columns="target", axis=1)
Y = heart_data["target"]

# %%
print(X)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal
# 0        0   0     1
# 1        0   0     2
# 2        2   0     2
# ...

# %%
print(Y)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2, stratify=Y,random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (303, 13) (242, 13) (61, 13)

# %%
model = LogisticRegression(max_iter=1000)

# %%
model.fit(X_train,Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# #Model Evaluation

# %% [markdown]
# ##Accuracy Score

# %%
from sklearn.metrics import accuracy_score

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
X_train_accuracy = accuracy_score(X_train_prediction, Y_train)
print(X_train_accuracy)

print("Accuracy on Training Data = ", round(X_train_accuracy*100,2),"%")
# Out:
# 0.8553719008264463
# Accuracy on Training Data =  85.54 %

# %%
# accuracy on testing data
X_test_prediction = model.predict(X_test)
X_test_accuracy = accuracy_score(X_test_prediction, Y_test)
print(X_test_accuracy)

print("Accuracy on Testing Data = ", round(X_test_accuracy*100,2),"%")
# Out:
# 0.8032786885245902
# Accuracy on Testing Data =  80.33 %

# %% [markdown]
# ##Precision

# %%
from sklearn.metrics import precision_score

# %%
# Precision on training data
precision_train = precision_score(Y_train,X_train_prediction)

print("Precision for Training Data = ",precision_train)
# Out:
# Precision for Training Data =  0.8299319727891157

# %%
# Precision on testing data
precision_test = precision_score(Y_test,X_test_prediction)

print("Precision for Testing Data = ",precision_test)
# Out:
# Precision for Testing Data =  0.8181818181818182

# %% [markdown]
# ##Recall

# %%
from sklearn.metrics import recall_score

# %%
# Recall on training data
recall_train = recall_score(Y_train,X_train_prediction)

print("Recall for Training Data = ",recall_train)
# Out:
# Recall for Training Data =  0.9242424242424242

# %%
# Recall on testing data
recall_test = recall_score(Y_test,X_test_prediction)

print("Recall for Testing Data = ",recall_test)
# Out:
# Recall for Testing Data =  0.8181818181818182

# %% [markdown]
# ##F1 Score

# %%
from sklearn.metrics import f1_score

# %%
# f1_score on training data
f1_score_train = f1_score(Y_train,X_train_prediction)

print("F1 Score for Training Data = ",f1_score_train)
# Out:
# F1 Score for Training Data =  0.8745519713261649

# %%
# f1_score on testing data
f1_score_test = f1_score(Y_test,X_test_prediction)

print("F1 Score for Testing Data = ",f1_score_test)
# Out:
# F1 Score for Testing Data =  0.8181818181818182

# %% [markdown]
# #Precision, Recall & F1 Score - Function

# %%
def precision_recall_f1_score(true_labels, pred_labels):

  precision_value = precision_score(true_labels, pred_labels)
  recall_value = recall_score(true_labels, pred_labels)
  f1_score_value = f1_score(true_labels, pred_labels)

  print('Precision =',precision_value)
  print('Recall =',recall_value)
  print('F1 Score =',f1_score_value)

# %%
# classification metrics for training data
precision_recall_f1_score(Y_train, X_train_prediction)
# Out:
# Precision = 0.8299319727891157
# Recall = 0.9242424242424242
# F1 Score = 0.8745519713261649

# %%
# classification metrics for test data
precision_recall_f1_score(Y_test, X_test_prediction)
# Out:
# Precision = 0.8181818181818182
# Recall = 0.8181818181818182
# F1 Score = 0.8181818181818182

# %% [markdown]
# ###Also we can use

# %%
from sklearn.metrics import precision_recall_fscore_support

# %%
ans = precision_recall_fscore_support(Y_train, X_train_prediction)
print(ans)
# Out:
# (array([0.89473684, 0.82993197]), array([0.77272727, 0.92424242]), array([0.82926829, 0.87455197]), array([110, 132]))

# %%
ans = precision_recall_fscore_support(Y_test, X_test_prediction)
print(ans)
# Out:
# (array([0.78571429, 0.81818182]), array([0.78571429, 0.81818182]), array([0.78571429, 0.81818182]), array([28, 33]))
