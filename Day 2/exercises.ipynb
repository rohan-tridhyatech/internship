# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("salaries-by-college-major.csv")

# %%
df.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting               46,000.00                 77,100.00
# 1  Aerospace Engineering               57,700.00                101,000.00
# 2            Agriculture               42,600.00                 71,900.00
# 3           Anthropology               36,800.00                 61,500.00
# 4           Architecture               41,600.00                 76,800.00
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                          42,200.00                         152,000.00
# 1                          64,300.00                         161,000.00
# 2                          36,300.00                         150,000.00
# 3                          33,800.00                         138,000.00
# 4                          50,600.00                         136,000.00
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %%
df.shape
# Out:
# (51, 6)

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
df.isna()
# Out:
#     Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0                 False                   False                     False
# 1                 False                   False                     False
# 2                 False                   False                     False
# 3                 False                   False                     False
# 4                 False                   False                     False
# 5                 False                   False                     False
# 6                 False                   False                     False
# 7                 False                   False                     False
# 8                 False                   False                     False
# 9                 False                   False                     False
# 10                False                   False                     False
# 11                False                   False                     False
# ...

# %%
df.isnull().value_counts()
# Out:
# Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  Group
# False                False                   False                     False                              False                              False    50
#                      True                    True                      True                               True                               True      1
# Name: count, dtype: int64

# %%
df.tail()
# Out:
#       Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 46             Psychology               35,900.00                 60,400.00
# 47               Religion               34,100.00                 52,000.00
# 48              Sociology               36,500.00                 58,200.00
# 49                Spanish               34,000.00                 53,100.00
# 50  Source: PayScale Inc.                     NaN                       NaN
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 46                          31,600.00                         127,000.00  HASS
# 47                          29,700.00                          96,400.00  HASS
# 48                          30,700.00                         118,000.00  HASS
# 49                          31,000.00                          96,400.00  HASS
# 50                                NaN                                NaN   NaN

# %%
clean_df = df.dropna()

# %%
clean_df.tail(10)
# Out:
#     Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 40              Nursing               54,200.00                 67,000.00
# 41            Nutrition               39,900.00                 55,300.00
# 42           Philosophy               39,900.00                 81,200.00
# 43  Physician Assistant               74,300.00                 91,700.00
# 44              Physics               50,300.00                 97,300.00
# 45    Political Science               40,800.00                 78,200.00
# 46           Psychology               35,900.00                 60,400.00
# 47             Religion               34,100.00                 52,000.00
# 48            Sociology               36,500.00                 58,200.00
# 49              Spanish               34,000.00                 53,100.00
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 40                          47,600.00                          98,300.00
# ...

# %%
clean_df['Starting Median Salary']
# Out:
# 0    46,000.00
# 1    57,700.00
# 2    42,600.00
# 3    36,800.00
# 4    41,600.00
# 5    35,800.00
# 6    38,800.00
# 7    43,000.00
# 8    63,200.00
# 9    42,600.00
# 10   53,900.00
# 11   38,100.00
# 12   61,400.00
# 13   55,900.00
# 14   53,700.00
# 15   35,000.00
# 16   35,900.00
# 17   50,100.00
# 18   34,900.00
# 19   60,900.00
# 20   38,000.00
# 21   37,900.00
# 22   47,900.00
# 23   39,100.00
# 24   41,200.00
# 25   43,500.00
# 26   35,700.00
# 27   38,800.00
# 28   39,200.00
# 29   37,800.00
# 30   57,700.00
# 31   49,100.00
# 32   36,100.00
# 33   40,900.00
# 34   35,600.00
# 35   49,200.00
# 36   40,800.00
# 37   45,400.00
# 38   57,900.00
# 39   35,900.00
# 40   54,200.00
# 41   39,900.00
# 42   39,900.00
# 43   74,300.00
# 44   50,300.00
# 45   40,800.00
# 46   35,900.00
# 47   34,100.00
# 48   36,500.00
# 49   34,000.00
# Name: Starting Median Salary, dtype: float64

# %%
clean_df['Starting Median Salary'].max()
# Out:
# np.float64(74300.0)

# %%
clean_df['Starting Median Salary'].idxmax()
# Out:
# np.int64(43)

# %%
clean_df['Undergraduate Major'].loc[43]
# Out:
# 'Physician Assistant'

# %%
clean_df['Undergraduate Major'][43]
# Out:
# 'Physician Assistant'

# %%
clean_df.loc[43]
# Out:
# Undergraduate Major                  Physician Assistant
# Starting Median Salary                         74,300.00
# Mid-Career Median Salary                       91,700.00
# Mid-Career 10th Percentile Salary              66,400.00
# Mid-Career 90th Percentile Salary             124,000.00
# Group                                               STEM
# Name: 43, dtype: object

# %%
print(clean_df['Mid-Career Median Salary'].max())
print(f"Index for the max mid career salary: {clean_df['Mid-Career Median Salary'].idxmax()}")
clean_df['Undergraduate Major'][8]
# Out:
# 107000.0
# Index for the max mid career salary: 8
# 'Chemical Engineering'

# %%
print(clean_df['Starting Median Salary'].min())
clean_df['Undergraduate Major'].loc[clean_df['Starting Median Salary'].idxmin()]
# Out:
# 34000.0
# 'Spanish'

# %%
clean_df.loc[clean_df['Mid-Career Median Salary'].idxmin()]
# Out:
# Undergraduate Major                  Education
# Starting Median Salary               34,900.00
# Mid-Career Median Salary             52,000.00
# Mid-Career 10th Percentile Salary    29,300.00
# Mid-Career 90th Percentile Salary   102,000.00
# Group                                     HASS
# Name: 18, dtype: object

# %%
clean_df['Mid-Career 90th Percentile Salary'] - clean_df['Mid-Career 10th Percentile Salary']
# Out:
# 0    109,800.00
# 1     96,700.00
# 2    113,700.00
# 3    104,200.00
# 4     85,400.00
# 5     96,200.00
# 6     98,100.00
# 7    108,200.00
# 8    122,100.00
# 9    102,700.00
# 10    84,600.00
# 11   105,500.00
# 12    95,900.00
# 13    98,000.00
# 14   114,700.00
# 15    74,800.00
# 16   116,300.00
# 17   159,400.00
# 18    72,700.00
# 19    98,700.00
# 20    99,600.00
# 21   102,100.00
# 22   147,800.00
# 23    70,000.00
# 24    92,000.00
# 25   111,000.00
# 26    76,000.00
# 27    66,400.00
# 28   112,000.00
# 29    88,500.00
# 30   115,900.00
# 31    84,500.00
# 32    71,300.00
# 33   118,800.00
# 34   106,600.00
# 35   100,700.00
# 36   132,900.00
# 37   137,800.00
# 38    99,300.00
# 39   107,300.00
# 40    50,700.00
# 41    65,300.00
# 42   132,500.00
# 43    57,600.00
# 44   122,000.00
# 45   126,800.00
# 46    95,400.00
# 47    66,700.00
# 48    87,300.00
# 49    65,400.00
# dtype: float64

# %%
clean_df['Mid-Career 90th Percentile Salary'].subtract(clean_df['Mid-Career 10th Percentile Salary'])
# Out:
# 0    109,800.00
# 1     96,700.00
# 2    113,700.00
# 3    104,200.00
# 4     85,400.00
# 5     96,200.00
# 6     98,100.00
# 7    108,200.00
# 8    122,100.00
# 9    102,700.00
# 10    84,600.00
# 11   105,500.00
# 12    95,900.00
# 13    98,000.00
# 14   114,700.00
# 15    74,800.00
# 16   116,300.00
# 17   159,400.00
# 18    72,700.00
# 19    98,700.00
# 20    99,600.00
# 21   102,100.00
# 22   147,800.00
# 23    70,000.00
# 24    92,000.00
# 25   111,000.00
# 26    76,000.00
# 27    66,400.00
# 28   112,000.00
# 29    88,500.00
# 30   115,900.00
# 31    84,500.00
# 32    71,300.00
# 33   118,800.00
# 34   106,600.00
# 35   100,700.00
# 36   132,900.00
# 37   137,800.00
# 38    99,300.00
# 39   107,300.00
# 40    50,700.00
# 41    65,300.00
# 42   132,500.00
# 43    57,600.00
# 44   122,000.00
# 45   126,800.00
# 46    95,400.00
# 47    66,700.00
# 48    87,300.00
# 49    65,400.00
# dtype: float64

# %%
spread_col = clean_df['Mid-Career 90th Percentile Salary'] - clean_df['Mid-Career 10th Percentile Salary']
clean_df.insert(1, 'Spread', spread_col)
clean_df.head()
# Out:
#      Undergraduate Major     Spread  Starting Median Salary  \
# 0             Accounting 109,800.00               46,000.00
# 1  Aerospace Engineering  96,700.00               57,700.00
# 2            Agriculture 113,700.00               42,600.00
# 3           Anthropology 104,200.00               36,800.00
# 4           Architecture  85,400.00               41,600.00
#
#    Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 0                 77,100.00                          42,200.00
# 1                101,000.00                          64,300.00
# 2                 71,900.00                          36,300.00
# 3                 61,500.00                          33,800.00
# 4                 76,800.00                          50,600.00
#
#    Mid-Career 90th Percentile Salary     Group
# 0                         152,000.00  Business
# 1                         161,000.00      STEM
# 2                         150,000.00  Business
# ...

# %%
low_risk = clean_df.sort_values('Spread')
low_risk[['Undergraduate Major', 'Spread']].head()
# Out:
#            Undergraduate Major    Spread
# 40                     Nursing 50,700.00
# 43         Physician Assistant 57,600.00
# 41                   Nutrition 65,300.00
# 49                     Spanish 65,400.00
# 27  Health Care Administration 66,400.00

# %%
highest_potential = clean_df.sort_values(by="Mid-Career 90th Percentile Salary", ascending=False)
highest_potential[["Undergraduate Major","Mid-Career 90th Percentile Salary"]].head()
# Out:
#      Undergraduate Major  Mid-Career 90th Percentile Salary
# 17             Economics                         210,000.00
# 22               Finance                         195,000.00
# 8   Chemical Engineering                         194,000.00
# 37                  Math                         183,000.00
# 44               Physics                         178,000.00

# %%
highest_spread = clean_df.sort_values('Spread', ascending=False)
highest_spread[['Undergraduate Major', 'Spread']].head()
# Out:
#    Undergraduate Major     Spread
# 17           Economics 159,400.00
# 22             Finance 147,800.00
# 37                Math 137,800.00
# 36           Marketing 132,900.00
# 42          Philosophy 132,500.00

# %%
highest_spread = clean_df.sort_values('Mid-Career Median Salary', ascending=False)
highest_spread[['Undergraduate Major', 'Mid-Career Median Salary']].head()
# Out:
#        Undergraduate Major  Mid-Career Median Salary
# 8     Chemical Engineering                107,000.00
# 12    Computer Engineering                105,000.00
# 19  Electrical Engineering                103,000.00
# 1    Aerospace Engineering                101,000.00
# 17               Economics                 98,600.00

# %%
clean_df.groupby('Group').count()
# Out:
#           Undergraduate Major  Spread  Starting Median Salary  \
# Group
# Business                   12      12                      12
# HASS                       22      22                      22
# STEM                       16      16                      16
#
#           Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# Group
# Business                        12                                 12
# HASS                            22                                 22
# STEM                            16                                 16
#
#           Mid-Career 90th Percentile Salary
# Group
# Business                                 12
# HASS                                     22
# STEM                                     16

# %%
pd.options.display.float_format = '{:,.2f}'.format
numeric_cols = clean_df.select_dtypes(include='number').columns
# print(numeric_cols)
result = clean_df.groupby("Group")[numeric_cols].mean()
# result = clean_df.groupby("Group").mean()
print(result)
# Out:
#              Spread  Starting Median Salary  Mid-Career Median Salary  \
# Group
# Business 103,958.33               44,633.33                 75,083.33
# HASS      95,218.18               37,186.36                 62,968.18
# STEM     101,600.00               53,862.50                 90,812.50
#
#           Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# Group
# Business                          43,566.67                         147,525.00
# HASS                              34,145.45                         129,363.64
# STEM                              56,025.00                         157,625.00

# %%
clean_df.dtypes
# Out:
# Undergraduate Major                   object
# Spread                               float64
# Starting Median Salary               float64
# Mid-Career Median Salary             float64
# Mid-Career 10th Percentile Salary    float64
# Mid-Career 90th Percentile Salary    float64
# Group                                 object
# dtype: object

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Undergraduate Major                50 non-null     object
#  1   Spread                             50 non-null     float64
#  2   Starting Median Salary             50 non-null     float64
#  3   Mid-Career Median Salary           50 non-null     float64
#  4   Mid-Career 10th Percentile Salary  50 non-null     float64
#  5   Mid-Career 90th Percentile Salary  50 non-null     float64
#  6   Group                              50 non-null     object
# dtypes: float64(5), object(2)
# memory usage: 5.2+ KB

# %%
clean_df.describe()
# Out:
#           Spread  Starting Median Salary  Mid-Career Median Salary  \
# count      50.00                   50.00                     50.00
# mean   99,358.00               44,310.00                 74,786.00
# std    23,290.71                9,360.87                 16,088.40
# min    50,700.00               34,000.00                 52,000.00
# 25%    84,800.00               37,050.00                 60,825.00
# 50%    99,450.00               40,850.00                 72,000.00
# 75%   113,275.00               49,875.00                 88,750.00
# max   159,400.00               74,300.00                107,000.00
#
#        Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# count                              50.00                              50.00
# mean                           43,408.00                         142,766.00
# std                            12,000.78                          27,851.25
# ...

# %%
print("Mean")
for i in numeric_cols:
    print(f"{i} --> {clean_df[i].mean()}")
# Out:
# Mean
# Spread --> 99358.0
# Starting Median Salary --> 44310.0
# Mid-Career Median Salary --> 74786.0
# Mid-Career 10th Percentile Salary --> 43408.0
# Mid-Career 90th Percentile Salary --> 142766.0

# %%
print("Median")
for i in numeric_cols:
    print(f"{i} --> {clean_df[i].median()}")
# Out:
# Median
# Spread --> 99450.0
# Starting Median Salary --> 40850.0
# Mid-Career Median Salary --> 72000.0
# Mid-Career 10th Percentile Salary --> 39400.0
# Mid-Career 90th Percentile Salary --> 145500.0

# %%
print("Mode")
for i in numeric_cols:
    print(f"{i} --> {clean_df[i].mode()[0]}")
# Out:
# Mode
# Spread --> 50700.0
# Starting Median Salary --> 35900.0
# Mid-Career Median Salary --> 52000.0
# Mid-Career 10th Percentile Salary --> 33900.0
# Mid-Career 90th Percentile Salary --> 168000.0

# %%
mean_values = clean_df.mean(numeric_only=True)
median_values = clean_df.median(numeric_only=True)
mode_values = clean_df.mode(numeric_only=True).iloc[0]

# %%
mean_values
# Out:
# Spread                               99,358.00
# Starting Median Salary               44,310.00
# Mid-Career Median Salary             74,786.00
# Mid-Career 10th Percentile Salary    43,408.00
# Mid-Career 90th Percentile Salary   142,766.00
# dtype: float64

# %%
median_values
# Out:
# Spread                               99,450.00
# Starting Median Salary               40,850.00
# Mid-Career Median Salary             72,000.00
# Mid-Career 10th Percentile Salary    39,400.00
# Mid-Career 90th Percentile Salary   145,500.00
# dtype: float64

# %%
mode_values
# Out:
# Spread                               50,700.00
# Starting Median Salary               35,900.00
# Mid-Career Median Salary             52,000.00
# Mid-Career 10th Percentile Salary    33,900.00
# Mid-Career 90th Percentile Salary   168,000.00
# Name: 0, dtype: float64

# %% [markdown]
# # Numpy Opeartions

# %% [markdown]
# ### Reshaping

# %%
arr = clean_df.to_numpy()

# %%
arr
# Out:
# array([['Accounting', 109800.0, 46000.0, 77100.0, 42200.0, 152000.0,
#         'Business'],
#        ['Aerospace Engineering', 96700.0, 57700.0, 101000.0, 64300.0,
#         161000.0, 'STEM'],
#        ['Agriculture', 113700.0, 42600.0, 71900.0, 36300.0, 150000.0,
#         'Business'],
#        ['Anthropology', 104200.0, 36800.0, 61500.0, 33800.0, 138000.0,
#         'HASS'],
#        ['Architecture', 85400.0, 41600.0, 76800.0, 50600.0, 136000.0,
#         'Business'],
#        ['Art History', 96200.0, 35800.0, 64900.0, 28800.0, 125000.0,
#         'HASS'],
#        ['Biology', 98100.0, 38800.0, 64800.0, 36900.0, 135000.0, 'STEM'],
#        ['Business Management', 108200.0, 43000.0, 72100.0, 38800.0,
#         147000.0, 'Business'],
#        ['Chemical Engineering', 122100.0, 63200.0, 107000.0, 71900.0,
#         194000.0, 'STEM'],
#        ['Chemistry', 102700.0, 42600.0, 79900.0, 45300.0, 148000.0,
#         'STEM'],
# ...

# %%
arr.shape
# Out:
# (50, 7)

# %%
# Reshape the array to 10 rows and 7 columns
reshaped_arr = arr.reshape((7,50))

# %%
print(reshaped_arr)
# Out:
# [['Accounting' 109800.0 46000.0 77100.0 42200.0 152000.0 'Business'
#   'Aerospace Engineering' 96700.0 57700.0 101000.0 64300.0 161000.0
#   'STEM' 'Agriculture' 113700.0 42600.0 71900.0 36300.0 150000.0
#   'Business' 'Anthropology' 104200.0 36800.0 61500.0 33800.0 138000.0
#   'HASS' 'Architecture' 85400.0 41600.0 76800.0 50600.0 136000.0
#   'Business' 'Art History' 96200.0 35800.0 64900.0 28800.0 125000.0
#   'HASS' 'Biology' 98100.0 38800.0 64800.0 36900.0 135000.0 'STEM'
#   'Business Management']
#  [108200.0 43000.0 72100.0 38800.0 147000.0 'Business'
#   'Chemical Engineering' 122100.0 63200.0 107000.0 71900.0 194000.0
#   'STEM' 'Chemistry' 102700.0 42600.0 79900.0 45300.0 148000.0 'STEM'
#   'Civil Engineering' 84600.0 53900.0 90500.0 63400.0 148000.0 'STEM'
#   'Communications' 105500.0 38100.0 70000.0 37500.0 143000.0 'HASS'
#   'Computer Engineering' 95900.0 61400.0 105000.0 66100.0 162000.0 'STEM'
#   'Computer Science' 98000.0 55900.0 95500.0 56000.0 154000.0 'STEM'
# ...

# %%
reshaped_arr.shape
# Out:
# (7, 50)

# %%
pd.DataFrame(reshaped_arr)
# Out:
#            0                    1          2                      3   \
# 0  Accounting           109,800.00  46,000.00              77,100.00
# 1  108,200.00            43,000.00  72,100.00              38,800.00
# 2   53,700.00            88,900.00  56,300.00             171,000.00
# 3   68,500.00            33,900.00 136,000.00                   HASS
# 4   37,000.00           149,000.00       HASS  Hospitality & Tourism
# 5  146,000.00                 STEM  Marketing             132,900.00
# 6        HASS  Physician Assistant  57,600.00              74,300.00
#
#           4                 5                     6                      7   \
# 0  42,200.00        152,000.00              Business  Aerospace Engineering
# 1 147,000.00          Business  Chemical Engineering             122,100.00
# 2   Business  Criminal Justice             74,800.00              35,000.00
# 3    Finance        147,800.00             47,900.00              88,300.00
# ...

# %% [markdown]
# ### Filtering

# %%
high_salary_rows = arr[arr[:, 2].astype(float) > 60000]
high_salary_rows
# Out:
# array([['Chemical Engineering', 122100.0, 63200.0, 107000.0, 71900.0,
#         194000.0, 'STEM'],
#        ['Computer Engineering', 95900.0, 61400.0, 105000.0, 66100.0,
#         162000.0, 'STEM'],
#        ['Electrical Engineering', 98700.0, 60900.0, 103000.0, 69300.0,
#         168000.0, 'STEM'],
#        ['Physician Assistant', 57600.0, 74300.0, 91700.0, 66400.0,
#         124000.0, 'STEM']], dtype=object)

# %% [markdown]
# ### Slicing

# %%
# Access the 'Starting Median Salary' column (index 2)
starting_salaries = arr[:, 2]
print(starting_salaries)
print(len(starting_salaries))
# Out:
# [46000.0 57700.0 42600.0 36800.0 41600.0 35800.0 38800.0 43000.0 63200.0
#  42600.0 53900.0 38100.0 61400.0 55900.0 53700.0 35000.0 35900.0 50100.0
#  34900.0 60900.0 38000.0 37900.0 47900.0 39100.0 41200.0 43500.0 35700.0
#  38800.0 39200.0 37800.0 57700.0 49100.0 36100.0 40900.0 35600.0 49200.0
#  40800.0 45400.0 57900.0 35900.0 54200.0 39900.0 39900.0 74300.0 50300.0
#  40800.0 35900.0 34100.0 36500.0 34000.0]
# 50

# %%
# Access rows 0-4 and columns 1-3 (spread, starting, and mid-career median salary)
subset = arr[0:5, 1:4]
subset
# Out:
# array([[109800.0, 46000.0, 77100.0],
#        [96700.0, 57700.0, 101000.0],
#        [113700.0, 42600.0, 71900.0],
#        [104200.0, 36800.0, 61500.0],
#        [85400.0, 41600.0, 76800.0]], dtype=object)

# %%
# Calculate the mean of the 'Mid-Career Median Salary' (index 3)
mid_career_mean = np.mean(arr[:, 3].astype(float))
print(mid_career_mean)
# Out:
# 74786.0

# %%
# Find the maximum 'Spread' value (index 1)
max_spread = np.max(arr[:, 1].astype(float))
print(max_spread)
# Out:
# 159400.0
